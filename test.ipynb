# %%
from neural_ir.utils.dataset_utils import read_triplets

# %%
read_triplets('data/tiny-data-for-test/train_triplets.tsv')
# Out:
# [('399998', '4848817', '1010990'),
#  ('910153', '954343', '3449427'),
#  ('102003', '5458294', '5780920'),
#  ('820334', '2293501', '5507156'),
#  ('940996', '4147115', '7161802'),
#  ('581132', '1622092', '625563'),
#  ('581132', '1622092', '5028705'),
#  ('910153', '954343', '2957299'),
#  ('820334', '2293501', '1558332'),
#  ('133086', '6469933', '3945311'),
#  ('581132', '1622092', '3260161'),
#  ('797714', '3568394', '8574447'),
#  ('306143', '785116', '8475303'),
#  ('306143', '785116', '6092678'),
#  ('1161590', '455993', '773033'),
#  ('442371', '1534729', '4422962'),
#  ('380141', '1651730', '5018492'),
#  ('910153', '954343', '149242'),
#  ('306143', '785116', '2563147'),
#  ('887487', '2408004', '1897345'),
#  ('133086', '6469933', '4172893'),
#  ('66668', '3902061', '7948512'),
#  ('132684', '4575291', '6496889'),
#  ('889446', '3868464', '7230777'),
#  ('889446', '3868466', '7230777'),
#  ('910153', '954343', '7229071'),
#  ('820334', '2293501', '8548879'),
# ...
